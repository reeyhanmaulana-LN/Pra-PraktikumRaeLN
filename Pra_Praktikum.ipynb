# %% [markdown]
# <a href="https://colab.research.google.com/github/reeyhanmaulana-LN/Pra-PraktikumRaeLN/blob/main/Pra_Praktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Judul Program
print("--- DATA DIRI ---")

# Menampilkan nama
print("Nama            : Reyhan Maulana A.M")

# Menampilkan NPM
print("NPM             : 2605060031")

# Menampilkan tempat dan tanggal lahir
print("Tempat, Tanggal Lahir : Temanggung, 15 April 2008")

# Menampilkan alamat
print("Alamat          :  Catgawen Caturanom RT 01/RW 06 Parakan Temanggung")

# Menampilkan jenis kelamin
print("Jenis Kelamin   : Laki-laki")

# Menampilkan hobi
print("Hobi            : Gaming & 3D Maker")
# Out:
# --- DATA DIRI ---
# Nama            : Reyhan Maulana A.M
# NPM             : 2605060031
# Tempat, Tanggal Lahir : Temanggung, 15 April 2008
# Alamat          :  Catgawen Caturanom RT 01/RW 06 Parakan Temanggung
# Jenis Kelamin   : Laki-laki
# Hobi            : Gaming & 3D Maker

# %% [markdown]
# https://medium.com/@reeyhanmaulana.a.m/pra-praktikum-d2b84da88308?sharedUserId=reeyhanmaulana.a.m
